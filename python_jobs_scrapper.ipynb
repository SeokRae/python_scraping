# %% [markdown]
# # Python Web Crawling

# %%
import csv
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs
from urllib import parse

# %%
OK_URL = "https://remoteok.io"
STACK_OF_FLOW_URL = f"https://stackoverflow.com/jobs?sort=i"
WEWORK_URL = "https://weworkremotely.com"

# %% [markdown]
# ## remoeok Web Crawling

# %%
# job 만들기
def extract_ok_job(tr_job):
    title = tr_job.find("td", {"class": "company_and_position"}).find("h2").get_text(strip=True)
    company = tr_job['data-company']
    link = tr_job['data-url']
    
    # job dict 만들기
    job = {
        "link": f"{OK_URL}/{link}",
        "title": title,
        "company": company
    }
    return job

# job List 가져오기
def get_ok_jobs(word):
    OK_JOB_URL = f"{OK_URL}/remote-{word}-jobs"
    URL = parse.urlparse(OK_JOB_URL)
    print(URL.geturl())
    get_request = requests.get(URL.geturl())
    
    if get_request.status_code == 200:
        html_parse = bs(get_request.text, "html.parser")
        container = html_parse.find("div", {"class": "container"})
        table = container.find("table", {"id": "jobsboard"})
    
        tr_jobs = table.find_all("tr", {"class", "job"})
        jobs = []
        # job List만들기
        for tr_job in tr_jobs:
            job = extract_ok_job(tr_job)
            jobs.append(job)

    return jobs

# remoteok 사이트 Crawling
def get_remoteok_jobs(word):
    print(f"renmoteok scrapper...")
    jobs = get_ok_jobs(word)
    return jobs

# %% [markdown]
# ## Stack of Flow Web Crawling

# %%
# 페이징을 통한 큰 데이터 가져오기
def get_stack_last_page(word):
    try:
        request = requests.get(f"{STACK_OF_FLOW_URL}&q={word}")
        html_parse = bs(request.text, "html.parser")
        # pagination
        pagination = html_parse.find("div", {"class": "s-pagination"})
        pages = pagination.find_all("a")
        # next 제거후 마지막 page
        last_page = pages[-2].get_text(strip=True)
    except AttributeError:
        return 0
    return int(last_page)

# job 만들기
def extract_stack_job(html):
  
    div = html.find("div", {"class": "grid--cell fl1"})
    # title  
    title = div.find("h2").find("a")["title"]
    # company, location
    company, location = div.find("h3", {"class": "fs-body1"}).find_all("span", recursive=False)
    company = company.get_text(strip=True)
  
    # link
    job_id = html['data-jobid']

    return {
        "link": f"https://stackoverflow.com/jobs/{job_id}",
        "title": title, 
        "company": company
    }

# job List 가져오기
def get_stack_jobs(word, last_page):
    jobs = []
    for page in range(last_page):
        STACK_URL = f"{STACK_OF_FLOW_URL}&q={word}&pg={page + 1}"
        URL = parse.urlparse(STACK_URL)
        print(URL.geturl())
        
        get_request = requests.get(URL.geturl())
        html_parse = bs(get_request.text, "html.parser")
        results = html_parse.find_all("div", {"class": "-job"})
        
        for result in results:
            job = extract_stack_job(result)
            jobs.append(job)

    return jobs

# stack_of_flow 사이트 Crawling
def get_stack_of_flow_jobs(word):
    print(f"stack_of_flow scrapper...")
    last_page = get_stack_last_page(word)
    if last_page == 0:
        return
    jobs = get_stack_jobs(word, last_page)
    return jobs

# %% [markdown]
# ## weworkremotely Web Crawling

# %%
# job 가져오기
def extract_wework_job(job_section):
    article = job_section.find("article")
    if article:
        job_list = article.find("ul").find_all("li")[:-1]
        jobs = []
            # li tags
        for job in job_list:
            a_section = job.select_one("li > a")
            if a_section:
                link = a_section['href'].strip()
                title = a_section.find("span", {"class": "title"}).get_text(strip=True)
                try:
                    (company, _, _,) = a_section.find_all("span", {"class": "company"})
                except ValueError:
                    (company, _,) = a_section.find_all("span", {"class": "company"})
          
                company = company.get_text(strip=True)

                cleaned_job = {
                    "link": f"{WEWORK_URL}/{link}",
                    "title": title,
                    "company": company
                }
                jobs.append(cleaned_job)

    return jobs

# job List 가져오기
def get_wework_jobs(word):
    WE_JOB_URL = f"{WEWORK_URL}/remote-jobs/search?term={word}"
    URL = parse.urlparse(WE_JOB_URL)
    print(URL.geturl())
    get_request = requests.get(URL.geturl())
    if get_request.status_code == 200:
        html_parse = bs(get_request.text, "html.parser")
        # jobs-container
        jobs_container = html_parse.find("div", {"class": "jobs-container"})
        # jobs
        job_section_list = jobs_container.find_all("section", {"class": "jobs"})

        aggregated_wework = []
        # section tags
        for job_section in job_section_list:
            job_list = extract_wework_job(job_section);
            aggregated_wework = aggregated_wework + job_list

        return aggregated_wework

# wework 사이트 Crawling
def get_weworkremotely_jobs(word):
    """ weworkremotely site scrapper """
    print(f"weworkremotely scrapper...")
    jobs = get_wework_jobs(word)

    return jobs

# %% [markdown]
# ## Aggregate Web Crawling

# %%
word = "python"
we = get_weworkremotely_jobs(word)
ok = get_remoteok_jobs(word)
stack = get_stack_of_flow_jobs(word)
jobs = we + ok + stack
# Out:
# weworkremotely scrapper...
# https://weworkremotely.com/remote-jobs/search?term=python
# renmoteok scrapper...
# https://remoteok.io/remote-python-jobs
# stack_of_flow scrapper...
# https://stackoverflow.com/jobs?sort=i&q=python&pg=1
# https://stackoverflow.com/jobs?sort=i&q=python&pg=2
# https://stackoverflow.com/jobs?sort=i&q=python&pg=3
# https://stackoverflow.com/jobs?sort=i&q=python&pg=4
# https://stackoverflow.com/jobs?sort=i&q=python&pg=5
# https://stackoverflow.com/jobs?sort=i&q=python&pg=6
# https://stackoverflow.com/jobs?sort=i&q=python&pg=7
# https://stackoverflow.com/jobs?sort=i&q=python&pg=8
# https://stackoverflow.com/jobs?sort=i&q=python&pg=9
# https://stackoverflow.com/jobs?sort=i&q=python&pg=10
# https://stackoverflow.com/jobs?sort=i&q=python&pg=11
# https://stackoverflow.com/jobs?sort=i&q=python&pg=12
# https://stackoverflow.com/jobs?sort=i&q=python&pg=13
# https://stackoverflow.com/jobs?sort=i&q=python&pg=14
# https://stackoverflow.com/jobs?sort=i&q=python&pg=15
# https://stackoverflow.com/jobs?sort=i&q=python&pg=16
# https://stackoverflow.com/jobs?sort=i&q=python&pg=17
# https://stackoverflow.com/jobs?sort=i&q=python&pg=18
# https://stackoverflow.com/jobs?sort=i&q=python&pg=19
# https://stackoverflow.com/jobs?sort=i&q=python&pg=20
# https://stackoverflow.com/jobs?sort=i&q=python&pg=21
# https://stackoverflow.com/jobs?sort=i&q=python&pg=22
# https://stackoverflow.com/jobs?sort=i&q=python&pg=23
# https://stackoverflow.com/jobs?sort=i&q=python&pg=24
# https://stackoverflow.com/jobs?sort=i&q=python&pg=25
# https://stackoverflow.com/jobs?sort=i&q=python&pg=26
# https://stackoverflow.com/jobs?sort=i&q=python&pg=27
# https://stackoverflow.com/jobs?sort=i&q=python&pg=28
# https://stackoverflow.com/jobs?sort=i&q=python&pg=29
# https://stackoverflow.com/jobs?sort=i&q=python&pg=30
# https://stackoverflow.com/jobs?sort=i&q=python&pg=31
# https://stackoverflow.com/jobs?sort=i&q=python&pg=32
# https://stackoverflow.com/jobs?sort=i&q=python&pg=33
# https://stackoverflow.com/jobs?sort=i&q=python&pg=34
# https://stackoverflow.com/jobs?sort=i&q=python&pg=35
# https://stackoverflow.com/jobs?sort=i&q=python&pg=36
# https://stackoverflow.com/jobs?sort=i&q=python&pg=37
# https://stackoverflow.com/jobs?sort=i&q=python&pg=38
# https://stackoverflow.com/jobs?sort=i&q=python&pg=39
# https://stackoverflow.com/jobs?sort=i&q=python&pg=40
# https://stackoverflow.com/jobs?sort=i&q=python&pg=41
# https://stackoverflow.com/jobs?sort=i&q=python&pg=42
# https://stackoverflow.com/jobs?sort=i&q=python&pg=43
# https://stackoverflow.com/jobs?sort=i&q=python&pg=44
# https://stackoverflow.com/jobs?sort=i&q=python&pg=45
# https://stackoverflow.com/jobs?sort=i&q=python&pg=46
# https://stackoverflow.com/jobs?sort=i&q=python&pg=47
# https://stackoverflow.com/jobs?sort=i&q=python&pg=48
# https://stackoverflow.com/jobs?sort=i&q=python&pg=49
# https://stackoverflow.com/jobs?sort=i&q=python&pg=50
# https://stackoverflow.com/jobs?sort=i&q=python&pg=51
# https://stackoverflow.com/jobs?sort=i&q=python&pg=52
# https://stackoverflow.com/jobs?sort=i&q=python&pg=53
# https://stackoverflow.com/jobs?sort=i&q=python&pg=54
# https://stackoverflow.com/jobs?sort=i&q=python&pg=55
# https://stackoverflow.com/jobs?sort=i&q=python&pg=56
# https://stackoverflow.com/jobs?sort=i&q=python&pg=57
# https://stackoverflow.com/jobs?sort=i&q=python&pg=58
# https://stackoverflow.com/jobs?sort=i&q=python&pg=59
# https://stackoverflow.com/jobs?sort=i&q=python&pg=60
# https://stackoverflow.com/jobs?sort=i&q=python&pg=61
# https://stackoverflow.com/jobs?sort=i&q=python&pg=62
# https://stackoverflow.com/jobs?sort=i&q=python&pg=63
# https://stackoverflow.com/jobs?sort=i&q=python&pg=64
# https://stackoverflow.com/jobs?sort=i&q=python&pg=65
# https://stackoverflow.com/jobs?sort=i&q=python&pg=66
# https://stackoverflow.com/jobs?sort=i&q=python&pg=67
# https://stackoverflow.com/jobs?sort=i&q=python&pg=68
# https://stackoverflow.com/jobs?sort=i&q=python&pg=69
# https://stackoverflow.com/jobs?sort=i&q=python&pg=70
# https://stackoverflow.com/jobs?sort=i&q=python&pg=71
# https://stackoverflow.com/jobs?sort=i&q=python&pg=72
# https://stackoverflow.com/jobs?sort=i&q=python&pg=73
# https://stackoverflow.com/jobs?sort=i&q=python&pg=74
# https://stackoverflow.com/jobs?sort=i&q=python&pg=75
# https://stackoverflow.com/jobs?sort=i&q=python&pg=76
# https://stackoverflow.com/jobs?sort=i&q=python&pg=77
# https://stackoverflow.com/jobs?sort=i&q=python&pg=78
# https://stackoverflow.com/jobs?sort=i&q=python&pg=79
# https://stackoverflow.com/jobs?sort=i&q=python&pg=80
# https://stackoverflow.com/jobs?sort=i&q=python&pg=81
# https://stackoverflow.com/jobs?sort=i&q=python&pg=82
# https://stackoverflow.com/jobs?sort=i&q=python&pg=83
# https://stackoverflow.com/jobs?sort=i&q=python&pg=84
# https://stackoverflow.com/jobs?sort=i&q=python&pg=85
# https://stackoverflow.com/jobs?sort=i&q=python&pg=86
# https://stackoverflow.com/jobs?sort=i&q=python&pg=87
# https://stackoverflow.com/jobs?sort=i&q=python&pg=88
# https://stackoverflow.com/jobs?sort=i&q=python&pg=89
# https://stackoverflow.com/jobs?sort=i&q=python&pg=90
# https://stackoverflow.com/jobs?sort=i&q=python&pg=91
# https://stackoverflow.com/jobs?sort=i&q=python&pg=92
# https://stackoverflow.com/jobs?sort=i&q=python&pg=93
# https://stackoverflow.com/jobs?sort=i&q=python&pg=94
# https://stackoverflow.com/jobs?sort=i&q=python&pg=95
# https://stackoverflow.com/jobs?sort=i&q=python&pg=96
# https://stackoverflow.com/jobs?sort=i&q=python&pg=97
# https://stackoverflow.com/jobs?sort=i&q=python&pg=98
# https://stackoverflow.com/jobs?sort=i&q=python&pg=99
# https://stackoverflow.com/jobs?sort=i&q=python&pg=100
# https://stackoverflow.com/jobs?sort=i&q=python&pg=101
# https://stackoverflow.com/jobs?sort=i&q=python&pg=102
# https://stackoverflow.com/jobs?sort=i&q=python&pg=103
# https://stackoverflow.com/jobs?sort=i&q=python&pg=104
# https://stackoverflow.com/jobs?sort=i&q=python&pg=105
# https://stackoverflow.com/jobs?sort=i&q=python&pg=106
# https://stackoverflow.com/jobs?sort=i&q=python&pg=107
# https://stackoverflow.com/jobs?sort=i&q=python&pg=108
# https://stackoverflow.com/jobs?sort=i&q=python&pg=109
# https://stackoverflow.com/jobs?sort=i&q=python&pg=110
# https://stackoverflow.com/jobs?sort=i&q=python&pg=111
# https://stackoverflow.com/jobs?sort=i&q=python&pg=112
# https://stackoverflow.com/jobs?sort=i&q=python&pg=113
# https://stackoverflow.com/jobs?sort=i&q=python&pg=114
# https://stackoverflow.com/jobs?sort=i&q=python&pg=115
# https://stackoverflow.com/jobs?sort=i&q=python&pg=116
# https://stackoverflow.com/jobs?sort=i&q=python&pg=117
# https://stackoverflow.com/jobs?sort=i&q=python&pg=118
# https://stackoverflow.com/jobs?sort=i&q=python&pg=119
# https://stackoverflow.com/jobs?sort=i&q=python&pg=120
# https://stackoverflow.com/jobs?sort=i&q=python&pg=121
# https://stackoverflow.com/jobs?sort=i&q=python&pg=122
# https://stackoverflow.com/jobs?sort=i&q=python&pg=123
# https://stackoverflow.com/jobs?sort=i&q=python&pg=124
# https://stackoverflow.com/jobs?sort=i&q=python&pg=125
# https://stackoverflow.com/jobs?sort=i&q=python&pg=126
# https://stackoverflow.com/jobs?sort=i&q=python&pg=127
# https://stackoverflow.com/jobs?sort=i&q=python&pg=128
# https://stackoverflow.com/jobs?sort=i&q=python&pg=129
# https://stackoverflow.com/jobs?sort=i&q=python&pg=130
# https://stackoverflow.com/jobs?sort=i&q=python&pg=131
# https://stackoverflow.com/jobs?sort=i&q=python&pg=132
# https://stackoverflow.com/jobs?sort=i&q=python&pg=133
# https://stackoverflow.com/jobs?sort=i&q=python&pg=134
# https://stackoverflow.com/jobs?sort=i&q=python&pg=135
# https://stackoverflow.com/jobs?sort=i&q=python&pg=136
# https://stackoverflow.com/jobs?sort=i&q=python&pg=137
# https://stackoverflow.com/jobs?sort=i&q=python&pg=138
# https://stackoverflow.com/jobs?sort=i&q=python&pg=139
# https://stackoverflow.com/jobs?sort=i&q=python&pg=140
# https://stackoverflow.com/jobs?sort=i&q=python&pg=141
# https://stackoverflow.com/jobs?sort=i&q=python&pg=142
# https://stackoverflow.com/jobs?sort=i&q=python&pg=143
# https://stackoverflow.com/jobs?sort=i&q=python&pg=144
# https://stackoverflow.com/jobs?sort=i&q=python&pg=145
# https://stackoverflow.com/jobs?sort=i&q=python&pg=146
# https://stackoverflow.com/jobs?sort=i&q=python&pg=147
# https://stackoverflow.com/jobs?sort=i&q=python&pg=148
# https://stackoverflow.com/jobs?sort=i&q=python&pg=149
# https://stackoverflow.com/jobs?sort=i&q=python&pg=150
# https://stackoverflow.com/jobs?sort=i&q=python&pg=151
# https://stackoverflow.com/jobs?sort=i&q=python&pg=152
# https://stackoverflow.com/jobs?sort=i&q=python&pg=153
# https://stackoverflow.com/jobs?sort=i&q=python&pg=154
# https://stackoverflow.com/jobs?sort=i&q=python&pg=155
# https://stackoverflow.com/jobs?sort=i&q=python&pg=156
# https://stackoverflow.com/jobs?sort=i&q=python&pg=157
# https://stackoverflow.com/jobs?sort=i&q=python&pg=158
# https://stackoverflow.com/jobs?sort=i&q=python&pg=159
# https://stackoverflow.com/jobs?sort=i&q=python&pg=160
# https://stackoverflow.com/jobs?sort=i&q=python&pg=161
# https://stackoverflow.com/jobs?sort=i&q=python&pg=162
# https://stackoverflow.com/jobs?sort=i&q=python&pg=163

# %% [markdown]
# ## Save CSV File

# %%
def save_to_file(term, jobs):
    file = open(f"csv_file/{term}.csv", mode="w", encoding='UTF-8', newline='')
    write = csv.writer(file)
    write.writerow([*jobs[0].keys()])
    for job in jobs:
        write.writerow([*job.values()])
    file.close()

# %%
save_to_file(word, jobs)

# %% [markdown]
# ## Read CSV File

# %%
df = pd.read_csv(f"csv_file/{word}.csv", low_memory=False, encoding='UTF-8')
df
# Out:
#                                                    link  \
# 0     https://weworkremotely.com//remote-jobs/good-e...
# 1     https://weworkremotely.com//remote-jobs/qualio...
# 2     https://weworkremotely.com//remote-jobs/mokriy...
# 3     https://weworkremotely.com//remote-jobs/fyi-se...
# 4     https://weworkremotely.com//remote-jobs/clickf...
# ...                                                 ...
# 4300              https://stackoverflow.com/jobs/286010
# 4301              https://stackoverflow.com/jobs/356110
# 4302              https://stackoverflow.com/jobs/369459
# 4303              https://stackoverflow.com/jobs/377821
# 4304              https://stackoverflow.com/jobs/369439
#
#                                                   title  \
# 0                     Senior Software Engineer - Mobile
# 1                             Senior Software Developer
# 2                                 Senior Scala Engineer
# 3                          Senior Integrations Engineer
# 4     Senior Fullstack Engineer (VueJS + Rails API /...
# ...                                                 ...
# 4300                              C++ Embedded Engineer
# 4301                      Teamlead Frontend Engineering
# 4302  Full Stack -kehittäjä Sitowisen Smart City -ra...
# 4303     Information Security Professional Lead Analyst
# 4304                           Senior Software Engineer
#
#                           company
# 0                       Good Eggs
# 1                          Qualio
# 2                     Mokriya Inc
# 3                             FYI
# 4                       ClickFlow
# ...                           ...
# 4300                   OSPIN GmbH
# 4301                      Make.TV
# 4302                     Sitowise
# 4303  Citibank, N.A.viaPandoLogic
# 4304            Epidemic Sound AB
#
# [4305 rows x 3 columns]
